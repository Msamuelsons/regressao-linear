# %% [markdown]
# <a href="https://colab.research.google.com/github/Msamuelsons/regressao-linear/blob/main/regress%C3%A3o_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
#gerando uma massa de dados
x, y = make_regression(n_samples=300, n_features=1, noise=30)

#mostrando o gráfico
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

#criação do modelo
modelo = LinearRegression()

# %%
modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
coef_linear = modelo.intercept_ #coeficiente linear

# %%
#y = mx + b
#m = 91.45 ou modelo.intercept_
#b = modelo.coef
coef_angular = modelo.coef_#coeficiente angular

# %%
#mostrando resultado
import numpy as np
plt.scatter(x, y)

xreg = np.arange(-3, 3, 1)
plt.plot(xreg, coef_angular*xreg+coef_linear, color='black') #gráfico regressão
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.30) # pega 30% do total de dados para teste

# %%
modelo.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %%
resultado = modelo.score(x_teste, y_teste) # coeficiente de determinação

# %%
print(resultado * 100)
# Out:
# 85.26376856739007

# %%
plt.scatter(x_teste, y_teste)

xreg = np.arange(-3, 3, 1)
plt.plot(xreg, coef_angular*xreg+coef_linear, color='black') #gráfico regressão
plt.show()
